# %% [markdown]
# # Primer Programa en Phyton
# ## Hola mundo desde Python
# * Nombre: Omar Recalde
# * Fecha : **23-06-2026**
# * Repositorio : <a href="https://github.com/OmaRecalde/machinelearning2026">Link del respositorio de Github</a>

# %% [markdown]
# # Comentario en python enviado dede python
# print("Hola mundo desde Pyhton")
